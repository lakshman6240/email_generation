# %%
Lakshman_resume = """
Technical Skills:
- Python, SQL, PySpark
- Azure Databricks, ADF, ADLS, Synapse
- SQL Server, Oracle, Snowflake
- Git, Azure DevOps CI/CD, Prefect
- ETL/ELT, Medallion Architecture
 
Experience (Data Engineer at TCS | 2 years 10 months):
- Built data pipelines with Databricks, ADF, Synapse
- Migrated Oracle EDW to Databricks/Snowflake
- Optimized clusters (20% compute cost reduction)
- Pandas → PySpark conversion for large datasets
- Prefect orchestration + CI/CD pipelines
- Pipeline monitoring & alerting systems
 
Key Achievements:
- 20% compute cost, 10% storage cost reduction
- 3x 'High Five' client awards
"""

# %%
Geethika_resume = """
Technical Skills:
- Python, PySpark
- Azure Databricks, ADF, ADLS Gen2
- Oracle SQL, SQL Server
- GitHub, Azure DevOps CI/CD
- Prefect orchestration, ETL
 
Experience (Data Engineer at TCS | 4+ years):
- Built scalable PySpark ETL pipelines in Databricks
- Pandas → PySpark conversion for large datasets
- Optimized Databricks clusters (40% cost reduction)
- Migrated SQL Server → ADLS using Databricks/PySpark
- Prefect orchestration + CI/CD implementation
- Pipeline monitoring for long-running jobs
 
Key Achievements:
- 40% cloud cost reduction
- 3x 'High Five' client awards
- 'On the Spot' award at TCS
"""
